# %% [markdown]
# # Evaluation

# %%
from KBDr.kclient import *
from KBDr.kcore import *

client = kGymAsyncClient(
    base_url='<kGym API Endpoint>'
)

# %% [markdown]
# ## Load kBench

# %%
kb = kBench.load('./benchmarks/<benchmark-name>')

# %% [markdown]
# ## Evaluate patches on kGym

# %% [markdown]
# ### Load your patches as \<bugId, patch\> map

# %%
patches = {
    '<bugId>': '<patch>'
}
# NOTE: do `patches = None` to run w/o patches;
only_bug_ids = ['bug IDs']
# NOTE: do `only_bug_ids = None` to run the entire run;

# %% [markdown]
# ### Run

# %%
result = await kb.evaluate_kgym(
    client,
    patches=patches,
    only_bug_ids=only_bug_ids
)
